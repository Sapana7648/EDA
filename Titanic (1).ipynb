# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv(r"D:\archive (1)\Titanic.csv")

# %%
dataset
# Out:
#      PassengerId  Pclass               Name     Sex  Age  SibSp  Parch  \
# 0              1       3       Allison Hill    male   17      4      2
# 1              2       1        Noah Rhodes    male   60      2      2
# 2              3       3    Angie Henderson    male   64      0      0
# 3              4       3      Daniel Wagner    male   35      4      0
# 4              5       1    Cristian Santos  female   70      0      3
# ..           ...     ...                ...     ...  ...    ...    ...
# 995          996       2      Brittany Ward    male   69      2      3
# 996          997       2     Edward Stanley  female   61      4      4
# 997          998       3  Christina Johnson    male   10      4      1
# 998          999       3       Edgar Miller    male   50      3      2
# 999         1000       1  Elizabeth Sanders    male    3      3      3
#
#                                    Ticket    Fare Embarked  Survived
# ...

# %%
dataset.head()
# Out:
#    PassengerId  Pclass             Name     Sex  Age  SibSp  Parch  \
# 0            1       3     Allison Hill    male   17      4      2
# 1            2       1      Noah Rhodes    male   60      2      2
# 2            3       3  Angie Henderson    male   64      0      0
# 3            4       3    Daniel Wagner    male   35      4      0
# 4            5       1  Cristian Santos  female   70      0      3
#
#                                  Ticket    Fare Embarked  Survived
# 0  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# 1  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04        S         0
# 2  61a66444-e2af-4629-9efb-336e2f546033   50.31        Q         1
# 3  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20        C         1
# 4  436e3c49-770e-49db-b092-d40143675d58  160.17        C         1

# %%
dataset.tail()
# Out:
#      PassengerId  Pclass               Name     Sex  Age  SibSp  Parch  \
# 995          996       2      Brittany Ward    male   69      2      3
# 996          997       2     Edward Stanley  female   61      4      4
# 997          998       3  Christina Johnson    male   10      4      1
# 998          999       3       Edgar Miller    male   50      3      2
# 999         1000       1  Elizabeth Sanders    male    3      3      3
#
#                                    Ticket    Fare Embarked  Survived
# 995  75eb0e8f-a090-460d-a7c7-655a7b434a72   19.87        Q         1
# 996  e55b93ad-8976-4471-9d7f-57d1e45def26   85.35        C         0
# 997  d06d3943-c8b3-415e-b664-704355c9bf0f  444.22        C         0
# 998  0e5779ec-be1a-470f-ad83-a4c869f8d3e4  234.67        S         1
# 999  90a014ab-4ca1-4abd-8565-0e0bd5c97d5d  286.65        C         1

# %%
dataset.head(500-505)
# Out:
#      PassengerId  Pclass               Name     Sex  Age  SibSp  Parch  \
# 0              1       3       Allison Hill    male   17      4      2
# 1              2       1        Noah Rhodes    male   60      2      2
# 2              3       3    Angie Henderson    male   64      0      0
# 3              4       3      Daniel Wagner    male   35      4      0
# 4              5       1    Cristian Santos  female   70      0      3
# ..           ...     ...                ...     ...  ...    ...    ...
# 990          991       2     Carmen Preston    male   47      0      1
# 991          992       3       Brian Harris  female   78      1      3
# 992          993       2      Michael Bowen    male   75      2      1
# 993          994       3   Deborah Campbell  female    9      4      1
# 994          995       2  Anthony Armstrong  female   16      2      2
#
#                                    Ticket    Fare Embarked  Survived
# ...

# %%
dataset.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Survived       0
# dtype: int64

# %%
dataset1=dataset.dropna()

# %%
dataset1
# Out:
#      PassengerId  Pclass               Name     Sex  Age  SibSp  Parch  \
# 0              1       3       Allison Hill    male   17      4      2
# 1              2       1        Noah Rhodes    male   60      2      2
# 2              3       3    Angie Henderson    male   64      0      0
# 3              4       3      Daniel Wagner    male   35      4      0
# 4              5       1    Cristian Santos  female   70      0      3
# ..           ...     ...                ...     ...  ...    ...    ...
# 995          996       2      Brittany Ward    male   69      2      3
# 996          997       2     Edward Stanley  female   61      4      4
# 997          998       3  Christina Johnson    male   10      4      1
# 998          999       3       Edgar Miller    male   50      3      2
# 999         1000       1  Elizabeth Sanders    male    3      3      3
#
#                                    Ticket    Fare Embarked  Survived
# ...

# %%
dataset1.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Survived       0
# dtype: int64

# %%
dataset1.select_dtypes(include=['number']).skew()
# Out:
# PassengerId    0.000000
# Pclass         0.066614
# Age            0.120351
# SibSp         -0.068930
# Parch          0.004003
# Fare           0.050159
# Survived       0.032052
# dtype: float64

# %%
dataset1.select_dtypes(include=['number']).kurtosis()
# Out:
# PassengerId   -1.200000
# Pclass        -1.512039
# Age           -1.206213
# SibSp         -1.306298
# Parch         -1.275359
# Fare          -1.143595
# Survived      -2.002983
# dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(x="Sex",y="Age",data=dataset1)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
dataset1.plot(kind="scatter",x="Sex",y="Age")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.violinplot(x="Sex",y="Age",data=dataset1)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.pairplot(dataset)

# %%
dataset.select_dtypes(include=['number']).corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare  \
# PassengerId     1.000000 -0.028581 -0.060180  0.005650  0.051432 -0.014822
# Pclass         -0.028581  1.000000 -0.004145  0.000987 -0.005899  0.050952
# Age            -0.060180 -0.004145  1.000000  0.016709 -0.039179 -0.033666
# SibSp           0.005650  0.000987  0.016709  1.000000  0.013374  0.037322
# Parch           0.051432 -0.005899 -0.039179  0.013374  1.000000 -0.016533
# Fare           -0.014822  0.050952 -0.033666  0.037322 -0.016533  1.000000
# Survived       -0.008592  0.023685 -0.022637  0.034079 -0.063090 -0.018823
#
#              Survived
# PassengerId -0.008592
# Pclass       0.023685
# Age         -0.022637
# SibSp        0.034079
# Parch       -0.063090
# Fare        -0.018823
# Survived     1.000000

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1000 non-null   int64
#  1   Pclass       1000 non-null   int64
#  2   Name         1000 non-null   object
#  3   Sex          1000 non-null   object
#  4   Age          1000 non-null   int64
#  5   SibSp        1000 non-null   int64
#  6   Parch        1000 non-null   int64
#  7   Ticket       1000 non-null   object
#  8   Fare         1000 non-null   float64
#  9   Embarked     1000 non-null   object
#  10  Survived     1000 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 86.1+ KB

# %%
dataset1.describe()
# Out:
#        PassengerId       Pclass          Age        SibSp        Parch  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000     1.964000    38.458000     2.032000     2.005000
# std     288.819436     0.820596    23.103723     1.424431     1.410306
# min       1.000000     1.000000     1.000000     0.000000     0.000000
# 25%     250.750000     1.000000    19.000000     1.000000     1.000000
# 50%     500.500000     2.000000    36.500000     2.000000     2.000000
# 75%     750.250000     3.000000    59.000000     3.000000     3.000000
# max    1000.000000     3.000000    79.000000     4.000000     4.000000
#
#               Fare     Survived
# count  1000.000000  1000.000000
# mean    247.968650     0.492000
# std     139.301211     0.500186
# min      10.020000     0.000000
# 25%     126.295000     0.000000
# 50%     246.500000     0.000000
# 75%     365.662500     1.000000
# max     499.780000     1.000000

# %%
dataset1_renamed = dataset1.rename(columns={'PassengerId': 'Id'})

# %%
dataset1_renamed
# Out:
#        Id  Pclass               Name     Sex  Age  SibSp  Parch  \
# 0       1       3       Allison Hill    male   17      4      2
# 1       2       1        Noah Rhodes    male   60      2      2
# 2       3       3    Angie Henderson    male   64      0      0
# 3       4       3      Daniel Wagner    male   35      4      0
# 4       5       1    Cristian Santos  female   70      0      3
# ..    ...     ...                ...     ...  ...    ...    ...
# 995   996       2      Brittany Ward    male   69      2      3
# 996   997       2     Edward Stanley  female   61      4      4
# 997   998       3  Christina Johnson    male   10      4      1
# 998   999       3       Edgar Miller    male   50      3      2
# 999  1000       1  Elizabeth Sanders    male    3      3      3
#
#                                    Ticket    Fare Embarked  Survived
# 0    43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# ...

# %%
#new column order
new_order = ['Age','Sex']
dataset1_reindexed = dataset1.reindex(columns=new_order)

# %%
dataset1_reindexed
# Out:
#      Age     Sex
# 0     17    male
# 1     60    male
# 2     64    male
# 3     35    male
# 4     70  female
# ..   ...     ...
# 995   69    male
# 996   61  female
# 997   10    male
# 998   50    male
# 999    3    male
#
# [1000 rows x 2 columns]
